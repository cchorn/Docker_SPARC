# %% [markdown]
# # 1) Check Python 3 version and packages

# %%
# !python --version
# Out:
# Python 3.6.6

# %%
# !pip3 freeze
# Out:
# altair==2.2.2
# asn1crypto==0.24.0
# backcall==0.1.0
# bleach==3.0.2
# bokeh==1.0.1
# brewer2mpl==1.4.1
# certifi==2018.10.15
# chardet==3.0.4
# cloudpickle==0.6.1
# cryptography==2.1.4
# cycler==0.10.0
# dask==0.20.0
# decorator==4.3.0
# defusedxml==0.5.0
# entrypoints==0.2.3
# ggplot==0.11.5
# h5py==2.8.0
# idna==2.6
# ipykernel==5.1.0
# ipython==7.1.1
# ipython-genutils==0.2.0
# ipywidgets==7.4.2
# jedi==0.13.1
# Jinja2==2.10
# jsonschema==2.6.0
# jupyter==1.0.0
# jupyter-client==5.2.3
# jupyter-console==6.0.0
# jupyter-contrib-core==0.3.3
# jupyter-contrib-nbextensions==0.5.0
# jupyter-core==4.4.0
# jupyter-highlight-selected-word==0.2.0
# jupyter-latex-envs==1.4.4
# jupyter-nbextensions-configurator==0.4.0
# jupyterlab==0.35.4
# jupyterlab-server==0.2.0
# jupytext==0.8.4
# keyring==10.6.0
# keyrings.alt==3.0
# kiwisolver==1.0.1
# lxml==4.2.5
# MarkupSafe==1.1.0
# matplotlib==3.0.1
# mistune==0.8.4
# mock==2.0.0
# mpmath==1.0.0
# nbconvert==5.4.0
# nbformat==4.4.0
# neo==0.5.2
# ...

# %% [markdown]
# # 2) Check Python 2 version and packages

# %%
# !python2 --version
# Out:
# Python 2.7.15rc1

# %%
# !pip2 freeze
# Out:
# asn1crypto==0.24.0
# backports-abc==0.5
# backports.functools-lru-cache==1.5
# backports.shutil-get-terminal-size==1.0.0
# blackfynn==2.6.3
# boto3==1.9.37
# botocore==1.12.37
# brewer2mpl==1.4.1
# certifi==2018.10.15
# chardet==3.0.4
# configparser==3.5.0
# cryptography==2.1.4
# cycler==0.10.0
# decorator==4.3.0
# docopt==0.6.2
# docutils==0.14
# enum34==1.1.6
# funcsigs==1.0.2
# functools32==3.2.3.post2
# future==0.17.1
# futures==3.2.0
# ggplot==0.11.5
# h5py==2.8.0
# idna==2.6
# ipaddress==1.0.17
# ipykernel==4.10.0
# ipython==5.8.0
# ipython-genutils==0.2.0
# jmespath==0.9.3
# jsonschema==2.6.0
# jupyter-client==5.2.3
# jupyter-core==4.4.0
# jupytext==0.8.4
# keyring==10.6.0
# keyrings.alt==3.0
# kiwisolver==1.0.1
# matplotlib==2.2.3
# mock==2.0.0
# nbformat==4.4.0
# neo==0.6.1
# numpy==1.15.4
# pandas==0.23.4
# pathlib2==2.3.2
# patsy==0.5.1
# pbr==5.1.1
# pexpect==4.6.0
# pickleshare==0.7.5
# plotly==3.4.0
# prompt-toolkit==1.0.15
# protobuf==3.2.0
# psutil==5.4.8
# ...

# %% [markdown]
# # 3) Check R version and packages

# %%
# !R --version
# Out:
# R version 3.4.4 (2018-03-15) -- "Someone to Lean On"
# Copyright (C) 2018 The R Foundation for Statistical Computing
# Platform: x86_64-pc-linux-gnu (64-bit)
#
# R is free software and comes with ABSOLUTELY NO WARRANTY.
# You are welcome to redistribute it under the terms of the
# GNU General Public License versions 2 or 3.
# For more information about these matters see
# http://www.gnu.org/licenses/.

# %%
# !Rscript -e "installed.packages()"
# Out:
#              Package        LibPath                         Version
# abind        "abind"        "/usr/local/lib/R/site-library" "1.4-5"
# assertthat   "assertthat"   "/usr/local/lib/R/site-library" "0.2.0"
# backports    "backports"    "/usr/local/lib/R/site-library" "1.1.2"
# base64enc    "base64enc"    "/usr/local/lib/R/site-library" "0.1-3"
# BH           "BH"           "/usr/local/lib/R/site-library" "1.66.0-1"
# bindr        "bindr"        "/usr/local/lib/R/site-library" "0.1.1"
# bindrcpp     "bindrcpp"     "/usr/local/lib/R/site-library" "0.2.2"
# bursts       "bursts"       "/usr/local/lib/R/site-library" "1.0-1"
# callr        "callr"        "/usr/local/lib/R/site-library" "3.0.0"
# car          "car"          "/usr/local/lib/R/site-library" "3.0-2"
# carData      "carData"      "/usr/local/lib/R/site-library" "3.0-2"
# cellranger   "cellranger"   "/usr/local/lib/R/site-library" "1.1.0"
# cli          "cli"          "/usr/local/lib/R/site-library" "1.0.1"
# ...
