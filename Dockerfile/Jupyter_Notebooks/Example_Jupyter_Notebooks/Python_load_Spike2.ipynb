# %% [markdown]
# # import Python modules

# %%
import neo
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # import Python script file

# %%
# load script files
# %run -i importSpike2.py

# %% [markdown]
# # load Spike2 file using function "importSpike2"

# %%
importSpike2(filename = "Data/test_spike2.smr", gain = 50, sample_rate = 20000, 
             save_start = 0, save_end = 30, display_start = 0, 
             display_end = 30, graph = True)
# Out:
# 17/02/2018
# 02:35:24
#
# ...
# test_spike2.smr:
# ...
# 600976.0 data points
# 30.05 sec
# 0.5 min
# 0.008 hr
# 20000 Hz
# float16
